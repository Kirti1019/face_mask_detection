# %%
# !pip install tensorflow==1.14.0

# %%
import os
root = "/content/drive/My Drive/TF_OD_9MAY/models/research"
os.chdir(root)

# %%
#!python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/ssd_mobilenet_v1_coco.config

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path training/ssd_mobilenet_v1_coco.config --trained_checkpoint_prefix training/model.ckpt-11183 --output_directory inference_graph
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/TF_OD_9MAY/models/research/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/TF_OD_9MAY/models/research/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From export_inference_graph.py:150: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From export_inference_graph.py:133: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0522 14:20:20.635667 139886327953280 deprecation_wrapper.py:119] From export_inference_graph.py:133: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...
